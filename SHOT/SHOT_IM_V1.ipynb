# %% [markdown]
# #Import drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Prepare data

# %% [markdown]
# #AR: 3 Activities

# %%
import pandas as pd
import numpy as np
np.random.seed(2021)
# !wget http://casas.wsu.edu/datasets/hh103.zip
# !wget http://casas.wsu.edu/datasets/hh101.zip
# !unzip '/content/hh101.zip'
# !unzip /content/hh103.zip

Final_Data_S1 = pd.read_csv("/content/hh103/hh103.ann.features.csv")
Final_Data_S2 = pd.read_csv("/content/hh101/hh101.ann.features.csv")

Final_Data_S1 = Final_Data_S1.drop(['lastSensorEventHours', 'lastSensorEventSeconds', 'lastSensorDayOfWeek','lastSensorID'], axis= 1)
Final_Data_S2 = Final_Data_S2.drop(['lastSensorEventHours', 'lastSensorEventSeconds','lastSensorDayOfWeek', 'lastSensorID'], axis= 1)

Final_Data_S1 = Final_Data_S1[Final_Data_S1.activity.isin(['Cook_Breakfast',  'Watch_TV', 'Toilet' ])]
Final_Data_S2 = Final_Data_S2[Final_Data_S2.activity.isin([ 'Cook_Breakfast',  'Watch_TV', 'Toilet' ])]

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.activity.isin(['Watch_TV'])].index,'activity']=0
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.activity.isin(['Toilet'])].index,'activity']=1
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.activity.isin(['Cook_Breakfast'])].index,'activity']=2

Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.activity.isin(['Watch_TV'])].index,'activity']=0
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.activity.isin(['Toilet'])].index,'activity']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.activity.isin(['Cook_Breakfast'])].index,'activity']=2

Data_0 = Final_Data_S1[Final_Data_S1.activity == 0].iloc[:2000]#2000(#4000 for unbalanced)
Data_2 = Final_Data_S1[Final_Data_S1.activity == 1].iloc[:2000]#2000
Data_3 = Final_Data_S1[Final_Data_S1.activity == 2].iloc[:2000]#2000
frames = [Data_0, Data_2, Data_3]
Final_Data_S1 = pd.concat(frames)

Data_0 = Final_Data_S2[Final_Data_S2.activity == 0].iloc[:1000]#1000(#2000 for unbalanced)
Data_2 = Final_Data_S2[Final_Data_S2.activity == 1].iloc[:1000]#1000
Data_3 = Final_Data_S2[Final_Data_S2.activity == 2].iloc[:1000]#1000
frames = [Data_0, Data_2, Data_3]
Final_Data_S2 = pd.concat(frames)


Final_Data_S1 = Final_Data_S1.sample(frac = 1)
Final_Data_S2 = Final_Data_S2.sample(frac = 1)


Source_train = Final_Data_S1.iloc[1000:,:]#1000
Source_test = Final_Data_S1.iloc[:1000,:]

Target_train = Final_Data_S2.iloc[500:,:]#500
Target_test = Final_Data_S2.iloc[:500,:]

Source_train.to_csv('/content/drive/MyDrive/SHOT_IM/data/Source_train.csv', index=False)
Source_test.to_csv('/content/drive/MyDrive/SHOT_IM/data/Source_test.csv', index=False)
Target_train.to_csv('/content/drive/MyDrive/SHOT_IM/data/Target_train.csv', index=False)
Target_test.to_csv('/content/drive/MyDrive/SHOT_IM/data/Target_test.csv', index=False)

# %% [markdown]
# #AR: 5 activities

# %%
import pandas as pd
import numpy as np
np.random.seed(2021)
# !wget http://casas.wsu.edu/datasets/hh103.zip
# !wget http://casas.wsu.edu/datasets/hh101.zip
# !unzip '/content/hh101.zip'
# !unzip /content/hh103.zip

Final_Data_S1 = pd.read_csv("/content/hh103/hh103.ann.features.csv")
Final_Data_S2 = pd.read_csv("/content/hh101/hh101.ann.features.csv")

Final_Data_S1 = Final_Data_S1.drop(['lastSensorEventHours', 'lastSensorEventSeconds', 'lastSensorDayOfWeek','lastSensorID'], axis= 1)
Final_Data_S2 = Final_Data_S2.drop(['lastSensorEventHours', 'lastSensorEventSeconds','lastSensorDayOfWeek', 'lastSensorID'], axis= 1)

Final_Data_S1 = Final_Data_S1[Final_Data_S1.activity.isin(['Cook_Dinner', 'Cook_Breakfast', 'Cook_Lunch', 'Watch_TV', 'Toilet' ])]
Final_Data_S2 = Final_Data_S2[Final_Data_S2.activity.isin(['Cook_Dinner', 'Cook_Breakfast', 'Cook_Lunch', 'Watch_TV', 'Toilet' ])]

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.activity.isin(['Watch_TV'])].index,'activity']=0
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.activity.isin(['Cook_Lunch'])].index,'activity']=1
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.activity.isin(['Toilet'])].index,'activity']=2
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.activity.isin(['Cook_Breakfast'])].index,'activity']=3
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.activity.isin(['Cook_Dinner'])].index,'activity']=4

Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.activity.isin(['Watch_TV'])].index,'activity']=0
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.activity.isin(['Cook_Lunch'])].index,'activity']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.activity.isin(['Toilet'])].index,'activity']=2
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.activity.isin(['Cook_Breakfast'])].index,'activity']=3
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.activity.isin(['Cook_Dinner'])].index,'activity']=4

Data_0 = Final_Data_S1[Final_Data_S1.activity == 0].iloc[:2000]#2000(#4000 for unbalanced)
Data_1 = Final_Data_S1[Final_Data_S1.activity == 1].iloc[:2000]#2000
Data_2 = Final_Data_S1[Final_Data_S1.activity == 2].iloc[:2000]#2000
Data_3 = Final_Data_S1[Final_Data_S1.activity == 3].iloc[:2000]#2000
Data_4 = Final_Data_S1[Final_Data_S1.activity == 4].iloc[:2000]#2000(#4000 for unbalanced)
frames = [Data_0, Data_1, Data_2, Data_3, Data_4]
Final_Data_S1 = pd.concat(frames)

Data_0 = Final_Data_S2[Final_Data_S2.activity == 0].iloc[:1000]#1000(#2000 for unbalanced)
Data_1 = Final_Data_S2[Final_Data_S2.activity == 1].iloc[:1000]#1000
Data_2 = Final_Data_S2[Final_Data_S2.activity == 2].iloc[:1000]#1000
Data_3 = Final_Data_S2[Final_Data_S2.activity == 3].iloc[:1000]#1000
Data_4 = Final_Data_S2[Final_Data_S2.activity == 4].iloc[:1000]#1000(#2000 for unbalanced)
frames = [Data_0, Data_1, Data_2, Data_3, Data_4]
Final_Data_S2 = pd.concat(frames)


Final_Data_S1 = Final_Data_S1.sample(frac = 1)
Final_Data_S2 = Final_Data_S2.sample(frac = 1)

Source_train = Final_Data_S1.iloc[1000:,:]#1000#
Source_test = Final_Data_S1.iloc[:1000,:]

Target_train = Final_Data_S2.iloc[500:,:]#500#
Target_test = Final_Data_S2.iloc[:500,:]

Source_train.to_csv('/content/drive/MyDrive/SHOT_IM/data/Source_train.csv', index=False)
Source_test.to_csv('/content/drive/MyDrive/SHOT_IM/data/Source_test.csv', index=False)
Target_train.to_csv('/content/drive/MyDrive/SHOT_IM/data/Target_train.csv', index=False)
Target_test.to_csv('/content/drive/MyDrive/SHOT_IM/data/Target_test.csv', index=False)

# %% [markdown]
# #OE: 2 labels unbalanced

# %%
import pandas as pd
import numpy as np
np.random.seed(2021)
Final_Data_S1 = pd.read_csv("/content/drive/MyDrive/Final_Data_S1.csv")
Final_Data_S2 = pd.read_csv("/content/drive/MyDrive/Final_Data_S2.csv")

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([3.0, 4.0])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([3.0, 4.0])].index,'labels']=1

# !pip install imbalanced-learn
from imblearn.over_sampling import SMOTE

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([0.0])].index,'labels']=0
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([1.0])].index,'labels']=1
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([2.0])].index,'labels']=1

Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([0.0])].index,'labels']=0
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([1.0])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([2.0])].index,'labels']=1

labels_S1 = Final_Data_S1.labels
labels_S2 = Final_Data_S2.labels
Data_S1 = Final_Data_S1.drop(['time', 'labels'], axis= 1)
Data_S2 = Final_Data_S2.drop(['time', 'labels'], axis= 1)

from sklearn.decomposition import PCA
pca = PCA(n_components=9)
principalComponents_S1 = pca.fit_transform(Data_S1)
pca = PCA(n_components=9)
principalComponents_S2 = pca.fit_transform(Data_S2)

sm = SMOTE(random_state=2)
principalComponents_S1, labels_S1 = sm.fit_resample(principalComponents_S1, labels_S1)
principalComponents_S2, labels_S2 = sm.fit_resample(principalComponents_S2, labels_S2)

Final_Data_S1 = pd.DataFrame(principalComponents_S1)
Final_Data_S2 = pd.DataFrame(principalComponents_S2)

Final_Data_S1['labels'] = labels_S1
Final_Data_S2['labels'] = labels_S2


Data_0 = Final_Data_S1[Final_Data_S1.labels == 0].iloc[:1045]
Data_2 = Final_Data_S1[Final_Data_S1.labels == 1].iloc[:300]
frames = [Data_0, Data_2]
Final_Data_S1 = pd.concat(frames)

Data_0 = Final_Data_S2[Final_Data_S2.labels == 0].iloc[:772]
Data_2 = Final_Data_S2[Final_Data_S2.labels == 1].iloc[:200]
frames = [Data_0, Data_2]
Final_Data_S2 = pd.concat(frames)

Final_Data_S1 = Final_Data_S1.sample(frac = 1)
Final_Data_S2 = Final_Data_S2.sample(frac = 1)

Source_train = Final_Data_S1.iloc[200:,:]
Source_test = Final_Data_S1.iloc[:200,:]

Target_train = Final_Data_S2.iloc[150:,:]
Target_test = Final_Data_S2.iloc[:150,:]

Source_train.to_csv('/content/drive/MyDrive/SHOT_IM/data/Source_train.csv', index=False)
Source_test.to_csv('/content/drive/MyDrive/SHOT_IM/data/Source_test.csv', index=False)
Target_train.to_csv('/content/drive/MyDrive/SHOT_IM/data/Target_train.csv', index=False)
Target_test.to_csv('/content/drive/MyDrive/SHOT_IM/data/Target_test.csv', index=False)
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (3.1.0)

# %% [markdown]
# #OE: 3 labels unbalanced

# %%
import pandas as pd
import numpy as np
np.random.seed(2021)
Final_Data_S1 = pd.read_csv("/content/drive/MyDrive/Final_Data_S1.csv")
Final_Data_S2 = pd.read_csv("/content/drive/MyDrive/Final_Data_S2.csv")

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([3.0, 4.0])].index,'labels']=2
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([3.0, 4.0])].index,'labels']=2

# !pip install imbalanced-learn
from imblearn.over_sampling import SMOTE

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([0.0])].index,'labels']=0
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([1.0])].index,'labels']=1
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([2.0])].index,'labels']=2

Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([0.0])].index,'labels']=0
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([1.0])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([2.0])].index,'labels']=2

labels_S1 = Final_Data_S1.labels
labels_S2 = Final_Data_S2.labels
Data_S1 = Final_Data_S1.drop(['time', 'labels'], axis= 1)
Data_S2 = Final_Data_S2.drop(['time', 'labels'], axis= 1)

from sklearn.decomposition import PCA
pca = PCA(n_components=9)
principalComponents_S1 = pca.fit_transform(Data_S1)
pca = PCA(n_components=9)
principalComponents_S2 = pca.fit_transform(Data_S2)

sm = SMOTE(random_state=2)
principalComponents_S1, labels_S1 = sm.fit_resample(principalComponents_S1, labels_S1)
principalComponents_S2, labels_S2 = sm.fit_resample(principalComponents_S2, labels_S2)

Final_Data_S1 = pd.DataFrame(principalComponents_S1)
Final_Data_S2 = pd.DataFrame(principalComponents_S2)

Final_Data_S1['labels'] = labels_S1
Final_Data_S2['labels'] = labels_S2


Data_0 = Final_Data_S1[Final_Data_S1.labels == 0].iloc[:1045]
Data_2 = Final_Data_S1[Final_Data_S1.labels == 1].iloc[:300]
Data_3 = Final_Data_S1[Final_Data_S1.labels == 2].iloc[:300]
frames = [Data_0, Data_2, Data_3]
Final_Data_S1 = pd.concat(frames)

Data_0 = Final_Data_S2[Final_Data_S2.labels == 0].iloc[:772]
Data_2 = Final_Data_S2[Final_Data_S2.labels == 1].iloc[:200]
Data_3 = Final_Data_S2[Final_Data_S2.labels == 2].iloc[:200]
frames = [Data_0, Data_2, Data_3]
Final_Data_S2 = pd.concat(frames)

Final_Data_S1 = Final_Data_S1.sample(frac = 1)
Final_Data_S2 = Final_Data_S2.sample(frac = 1)

Source_train = Final_Data_S1.iloc[200:,:]
Source_test = Final_Data_S1.iloc[:200,:]

Target_train = Final_Data_S2.iloc[150:,:]
Target_test = Final_Data_S2.iloc[:150,:]

Source_train.to_csv('/content/drive/MyDrive/SHOT_IM/data/Source_train.csv', index=False)
Source_test.to_csv('/content/drive/MyDrive/SHOT_IM/data/Source_test.csv', index=False)
Target_train.to_csv('/content/drive/MyDrive/SHOT_IM/data/Target_train.csv', index=False)
Target_test.to_csv('/content/drive/MyDrive/SHOT_IM/data/Target_test.csv', index=False)
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (3.1.0)

# %% [markdown]
# #OE: 2 labels balanced

# %%
import pandas as pd
import numpy as np
np.random.seed(2021)
Final_Data_S1 = pd.read_csv("/content/drive/MyDrive/Final_Data_S1.csv")
Final_Data_S2 = pd.read_csv("/content/drive/MyDrive/Final_Data_S2.csv")

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([3.0, 4.0])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([3.0, 4.0])].index,'labels']=1

# !pip install imbalanced-learn
from imblearn.over_sampling import SMOTE

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([0.0])].index,'labels']=0
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([1.0])].index,'labels']=1
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([2.0])].index,'labels']=1

Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([0.0])].index,'labels']=0
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([1.0])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([2.0])].index,'labels']=1

labels_S1 = Final_Data_S1.labels
labels_S2 = Final_Data_S2.labels
Data_S1 = Final_Data_S1.drop(['time', 'labels'], axis= 1)
Data_S2 = Final_Data_S2.drop(['time', 'labels'], axis= 1)

from sklearn.decomposition import PCA
pca = PCA(n_components=9)
principalComponents_S1 = pca.fit_transform(Data_S1)
pca = PCA(n_components=9)
principalComponents_S2 = pca.fit_transform(Data_S2)

sm = SMOTE(random_state=2)
principalComponents_S1, labels_S1 = sm.fit_resample(principalComponents_S1, labels_S1)
principalComponents_S2, labels_S2 = sm.fit_resample(principalComponents_S2, labels_S2)

Final_Data_S1 = pd.DataFrame(principalComponents_S1)
Final_Data_S2 = pd.DataFrame(principalComponents_S2)

Final_Data_S1['labels'] = labels_S1
Final_Data_S2['labels'] = labels_S2


Final_Data_S1 = Final_Data_S1.sample(frac = 1)
Final_Data_S2 = Final_Data_S2.sample(frac = 1)

Source_train = Final_Data_S1.iloc[500:,:]
Source_test = Final_Data_S1.iloc[:500,:]

Target_train = Final_Data_S2.iloc[500:,:]
Target_test = Final_Data_S2.iloc[:500,:]

Source_train.to_csv('/content/drive/MyDrive/SHOT_IM/data/Source_train.csv', index=False)
Source_test.to_csv('/content/drive/MyDrive/SHOT_IM/data/Source_test.csv', index=False)
Target_train.to_csv('/content/drive/MyDrive/SHOT_IM/data/Target_train.csv', index=False)
Target_test.to_csv('/content/drive/MyDrive/SHOT_IM/data/Target_test.csv', index=False)
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (3.1.0)

# %% [markdown]
# #OE: 3 labels balanced

# %%
import pandas as pd
import numpy as np
np.random.seed(2021)
Final_Data_S1 = pd.read_csv("/content/drive/MyDrive/Final_Data_S1.csv")
Final_Data_S2 = pd.read_csv("/content/drive/MyDrive/Final_Data_S2.csv")


Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([3.0, 4.0])].index,'labels']=2
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([3.0, 4.0])].index,'labels']=2

# !pip install imbalanced-learn
from imblearn.over_sampling import SMOTE

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([0.0])].index,'labels']=0
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([1.0])].index,'labels']=1
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([2.0])].index,'labels']=2

Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([0.0])].index,'labels']=0
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([1.0])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([2.0])].index,'labels']=2

labels_S1 = Final_Data_S1.labels
labels_S2 = Final_Data_S2.labels
Data_S1 = Final_Data_S1.drop(['time', 'labels'], axis= 1)
Data_S2 = Final_Data_S2.drop(['time', 'labels'], axis= 1)

from sklearn.decomposition import PCA
pca = PCA(n_components=9)
principalComponents_S1 = pca.fit_transform(Data_S1)
pca = PCA(n_components=9)
principalComponents_S2 = pca.fit_transform(Data_S2)

sm = SMOTE(random_state=2)
principalComponents_S1, labels_S1 = sm.fit_resample(principalComponents_S1, labels_S1)
principalComponents_S2, labels_S2 = sm.fit_resample(principalComponents_S2, labels_S2)

Final_Data_S1 = pd.DataFrame(principalComponents_S1)
Final_Data_S2 = pd.DataFrame(principalComponents_S2)

Final_Data_S1['labels'] = labels_S1
Final_Data_S2['labels'] = labels_S2


Final_Data_S1 = Final_Data_S1.sample(frac = 1)
Final_Data_S2 = Final_Data_S2.sample(frac = 1)

Source_train = Final_Data_S1.iloc[500:,:]
Source_test = Final_Data_S1.iloc[:500,:]

Target_train = Final_Data_S2.iloc[500:,:]
Target_test = Final_Data_S2.iloc[:500,:]

Source_train.to_csv('/content/drive/MyDrive/SHOT_IM/data/Source_train.csv', index=False)
Source_test.to_csv('/content/drive/MyDrive/SHOT_IM/data/Source_test.csv', index=False)
Target_train.to_csv('/content/drive/MyDrive/SHOT_IM/data/Target_train.csv', index=False)
Target_test.to_csv('/content/drive/MyDrive/SHOT_IM/data/Target_test.csv', index=False)
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (3.1.0)

# %% [markdown]
# #SHOT method

# %%
import os
os.chdir('/content/drive/MyDrive/SHOT_IM')

# %% [markdown]
# ##SHOT-IM

# %%
# !python uda_digit.py --dset s2m --gpu_id 0 --cls_par 0.0 --output ckps_digits
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:423/4230; Accuracy_Source = 71.40%/ 70.40%
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:846/4230; Accuracy_Source = 78.08%/ 78.80%
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:1269/4230; Accuracy_Source = 85.86%/ 86.00%
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:1692/4230; Accuracy_Source = 89.48%/ 89.70%
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:2115/4230; Accuracy_Source = 91.30%/ 91.10%
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:2538/4230; Accuracy_Source = 95.02%/ 96.00%
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:2961/4230; Accuracy_Source = 94.92%/ 95.30%
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:3384/4230; Accuracy_Source = 93.11%/ 93.50%
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:3807/4230; Accuracy_Source = 95.86%/ 96.10%
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:4230/4230; Accuracy_Source = 95.28%/ 95.90%
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Task: s2m, Accuracy_Test_0 = 46.20%; f1_score_Test_1 = 0.35788583280774866; f_score_Test_1 = [0.08247423 0.4048583  0.79338843 0.         0.52597403]; confusion_matrix_Test_1 = [[ 4 54 33  0  2]
#  [ 0 50 10  0 45]
#  [ 0  0 96  0  0]
#  [ 0 19  7  0 80]
#  [ 0 19  0  0 81]]
#
# Axes(0.125,0.11;0.62x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:71/2130; Accuracy_Test_1 = 50.80%; f1_score_Test_1 = 0.4921593264602758; f_score_Test_1 = [0.8375     0.40506329 0.7027027  0.         0.58201058]; confusion_matrix_Test_1 = [[ 67  20   0   0   6]
#  [  0  80   0   0  25]
#  [  0  39  52   2   3]
#  [  0 106   0   0   0]
#  [  0  45   0   0  55]]
#
# Axes(0.125,0.11;0.496x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:142/2130; Accuracy_Test_1 = 53.60%; f1_score_Test_1 = 0.508449807674266; f_score_Test_1 = [0.9122807  0.35555556 0.9197861  0.         0.4375    ]; confusion_matrix_Test_1 = [[78  6  5  0  4]
#  [ 0 48  0  8 49]
#  [ 0  8 86  2  0]
#  [ 0 59  0  0 47]
#  [ 0 44  0  0 56]]
#
# Axes(0.125,0.11;0.3968x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:213/2130; Accuracy_Test_1 = 55.40%; f1_score_Test_1 = 0.5331143098387682; f_score_Test_1 = [0.9122807  0.34545455 0.9197861  0.         0.57142857]; confusion_matrix_Test_1 = [[ 78  10   5   0   0]
#  [  0  57   0   8  40]
#  [  0   8  86   2   0]
#  [  0 106   0   0   0]
#  [  0  44   0   0  56]]
#
# Axes(0.125,0.11;0.31744x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:284/2130; Accuracy_Test_1 = 50.80%; f1_score_Test_1 = 0.48822859295386506; f_score_Test_1 = [0.83870968 0.30434783 0.8255814  0.         0.54901961]; confusion_matrix_Test_1 = [[ 78  10   5   0   0]
#  [  0  49   0   8  48]
#  [ 15   8  71   2   0]
#  [  0 106   0   0   0]
#  [  0  44   0   0  56]]
#
# Axes(0.125,0.11;0.253952x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:355/2130; Accuracy_Test_1 = 51.00%; f1_score_Test_1 = 0.49087113145045896; f_score_Test_1 = [0.84782609 0.29906542 0.83908046 0.         0.54634146]; confusion_matrix_Test_1 = [[ 78  10   5   0   0]
#  [  0  48   0   8  49]
#  [ 13   8  73   2   0]
#  [  0 106   0   0   0]
#  [  0  44   0   0  56]]
#
# Axes(0.125,0.11;0.203162x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:426/2130; Accuracy_Test_1 = 54.20%; f1_score_Test_1 = 0.5225942828885941; f_score_Test_1 = [0.9122807  0.30625    0.93121693 0.         0.54901961]; confusion_matrix_Test_1 = [[ 78  10   5   0   0]
#  [  0  49   0   8  48]
#  [  0   6  88   2   0]
#  [  0 106   0   0   0]
#  [  0  44   0   0  56]]
#
# Axes(0.125,0.11;0.162529x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:497/2130; Accuracy_Test_1 = 55.40%; f1_score_Test_1 = 0.5331143098387682; f_score_Test_1 = [0.9122807  0.34545455 0.9197861  0.         0.57142857]; confusion_matrix_Test_1 = [[ 78  10   5   0   0]
#  [  0  57   0   8  40]
#  [  0   8  86   2   0]
#  [  0 106   0   0   0]
#  [  0  44   0   0  56]]
#
# Axes(0.125,0.11;0.130023x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:568/2130; Accuracy_Test_1 = 53.80%; f1_score_Test_1 = 0.5200001060544875; f_score_Test_1 = [0.9122807  0.30434783 0.9197861  0.         0.54901961]; confusion_matrix_Test_1 = [[ 78  10   5   0   0]
#  [  0  49   0   8  48]
#  [  0   8  86   2   0]
#  [  0 106   0   0   0]
#  [  0  44   0   0  56]]
#
# Axes(0.125,0.11;0.104019x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:639/2130; Accuracy_Test_1 = 55.40%; f1_score_Test_1 = 0.5331143098387682; f_score_Test_1 = [0.9122807  0.34545455 0.9197861  0.         0.57142857]; confusion_matrix_Test_1 = [[ 78  10   5   0   0]
#  [  0  57   0   8  40]
#  [  0   8  86   2   0]
#  [  0 106   0   0   0]
#  [  0  44   0   0  56]]
#
# Axes(0.125,0.11;0.083215x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:710/2130; Accuracy_Test_1 = 55.40%; f1_score_Test_1 = 0.5331143098387682; f_score_Test_1 = [0.9122807  0.34545455 0.9197861  0.         0.57142857]; confusion_matrix_Test_1 = [[ 78  10   5   0   0]
#  [  0  57   0   8  40]
#  [  0   8  86   2   0]
#  [  0 106   0   0   0]
#  [  0  44   0   0  56]]
#
# Axes(0.125,0.11;0.066572x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:781/2130; Accuracy_Test_1 = 53.60%; f1_score_Test_1 = 0.5183551720082831; f_score_Test_1 = [0.9122807  0.29906542 0.9197861  0.         0.54634146]; confusion_matrix_Test_1 = [[ 78  10   5   0   0]
#  [  0  48   0   8  49]
#  [  0   8  86   2   0]
#  [  0 106   0   0   0]
#  [  0  44   0   0  56]]
#
# Axes(0.125,0.11;0.0532576x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:852/2130; Accuracy_Test_1 = 55.40%; f1_score_Test_1 = 0.5331143098387682; f_score_Test_1 = [0.9122807  0.34545455 0.9197861  0.         0.57142857]; confusion_matrix_Test_1 = [[ 78  10   5   0   0]
#  [  0  57   0   8  40]
#  [  0   8  86   2   0]
#  [  0 106   0   0   0]
#  [  0  44   0   0  56]]
#
# Axes(0.125,0.11;0.0426061x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:923/2130; Accuracy_Test_1 = 53.60%; f1_score_Test_1 = 0.5183551720082831; f_score_Test_1 = [0.9122807  0.29906542 0.9197861  0.         0.54634146]; confusion_matrix_Test_1 = [[ 78  10   5   0   0]
#  [  0  48   0   8  49]
#  [  0   8  86   2   0]
#  [  0 106   0   0   0]
#  [  0  44   0   0  56]]
#
# Axes(0.125,0.11;0.0340849x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:994/2130; Accuracy_Test_1 = 53.60%; f1_score_Test_1 = 0.5183551720082831; f_score_Test_1 = [0.9122807  0.29906542 0.9197861  0.         0.54634146]; confusion_matrix_Test_1 = [[ 78  10   5   0   0]
#  [  0  48   0   8  49]
#  [  0   8  86   2   0]
#  [  0 106   0   0   0]
#  [  0  44   0   0  56]]
#
# Axes(0.125,0.11;0.0272679x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:1065/2130; Accuracy_Test_1 = 53.60%; f1_score_Test_1 = 0.5183551720082831; f_score_Test_1 = [0.9122807  0.29906542 0.9197861  0.         0.54634146]; confusion_matrix_Test_1 = [[ 78  10   5   0   0]
#  [  0  48   0   8  49]
#  [  0   8  86   2   0]
#  [  0 106   0   0   0]
#  [  0  44   0   0  56]]
#
# Axes(0.125,0.11;0.0218143x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:1136/2130; Accuracy_Test_1 = 53.60%; f1_score_Test_1 = 0.5187489258535354; f_score_Test_1 = [0.9122807  0.30094044 0.9197861  0.         0.54634146]; confusion_matrix_Test_1 = [[ 78  10   5   0   0]
#  [  0  48   0   8  49]
#  [  0   6  86   4   0]
#  [  0 106   0   0   0]
#  [  0  44   0   0  56]]
#
# Axes(0.125,0.11;0.0174514x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:1207/2130; Accuracy_Test_1 = 53.60%; f1_score_Test_1 = 0.5183551720082831; f_score_Test_1 = [0.9122807  0.29906542 0.9197861  0.         0.54634146]; confusion_matrix_Test_1 = [[ 78  10   5   0   0]
#  [  0  48   0   8  49]
#  [  0   8  86   2   0]
#  [  0 106   0   0   0]
#  [  0  44   0   0  56]]
#
# Axes(0.125,0.11;0.0139612x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:1278/2130; Accuracy_Test_1 = 53.60%; f1_score_Test_1 = 0.5183551720082831; f_score_Test_1 = [0.9122807  0.29906542 0.9197861  0.         0.54634146]; confusion_matrix_Test_1 = [[ 78  10   5   0   0]
#  [  0  48   0   8  49]
#  [  0   8  86   2   0]
#  [  0 106   0   0   0]
#  [  0  44   0   0  56]]
#
# Axes(0.125,0.11;0.0111689x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task: s2m, Iter:1349/2130; Accuracy_Test_1 = 53.60%; f1_score_Test_1 = 0.5183551720082831; f_score_Test_1 = [0.9122807  0.29906542 0.9197861  0.         0.54634146]; confusion_matrix_Test_1 = [[ 78  10   5   0   0]
#  [  0  48   0   8  49]
#  [  0   8  86   2   0]
#  [  0 106   0   0   0]
#  [  0  44   0   0  56]]
#
# Axes(0.125,0.11;0.00893514x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/SHOT_IM/uda_digit.py", line 461, in <module>
#     train_target(args)
#   File "/content/drive/MyDrive/SHOT_IM/uda_digit.py", line 341, in train_target
#     optimizer.step()
#   File "/usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py", line 280, in wrapper
#     out = func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py", line 33, in _use_grad
#     ret = func(self, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/optim/sgd.py", line 76, in step
#     sgd(params_with_grad,
#   File "/usr/local/lib/python3.10/dist-packages/torch/optim/sgd.py", line 222, in sgd
#     func(params,
#   File "/usr/local/lib/python3.10/dist-packages/torch/optim/sgd.py", line 283, in _multi_tensor_sgd
#     grouped_tensors = _group_tensors_by_device_and_dtype([params, grads, momentum_buffer_list], with_indices=True)
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 114, in decorate_context
#     with ctx_factory():
#   File "/usr/local/lib/python3.10/dist-packages/torch/autograd/grad_mode.py", line 58, in __exit__
#     torch.set_grad_enabled(self.prev)
#   File "/usr/local/lib/python3.10/dist-packages/torch/autograd/grad_mode.py", line 149, in __init__
#     def __init__(self, mode: bool) -> None:
# KeyboardInterrupt
# ^C

# %% [markdown]
# ##Full SHOT

# %%
# !python uda_digit.py --dset s2m --gpu_id 0 --cls_par 0.1 --output ckps_digits
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Accuracy = 43.91% -> 38.76%
#
# Task: s2m, Iter:71/2130; Accuracy_Test_1 = 27.80%; f1_score_Test_1 = 0.27335844057586917; f_score_Test_1 = [0.53112033 0.19417476 0.55639098 0.         0.13483146]; confusion_matrix_Test_1 = [[64  1  0 14 14]
#  [25 20  0  8 52]
#  [ 3 12 37 25 19]
#  [ 0 42  0  0 64]
#  [56 26  0  0 18]]
#
# Axes(0.125,0.11;0.62x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Accuracy = 25.73% -> 26.62%
#
# Task: s2m, Iter:142/2130; Accuracy_Test_1 = 29.20%; f1_score_Test_1 = 0.26936028367548326; f_score_Test_1 = [0.53164557 0.32323232 0.53435115 0.         0.        ]; confusion_matrix_Test_1 = [[63 10  0 14  6]
#  [25 48  0  8 24]
#  [ 0 12 35 42  7]
#  [ 0 78  0  0 28]
#  [56 44  0  0  0]]
#
# Axes(0.125,0.11;0.496x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Accuracy = 26.58% -> 27.09%
#
# Task: s2m, Iter:213/2130; Accuracy_Test_1 = 30.40%; f1_score_Test_1 = 0.26996257981913935; f_score_Test_1 = [0.53488372 0.32323232 0.53435115 0.         0.        ]; confusion_matrix_Test_1 = [[69 10  0 13  1]
#  [40 48  0  8  9]
#  [ 0 12 35 42  7]
#  [ 0 78  0  0 28]
#  [56 44  0  0  0]]
#
# Axes(0.125,0.11;0.3968x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Accuracy = 28.33% -> 28.49%
#
# Task: s2m, Iter:284/2130; Accuracy_Test_1 = 30.40%; f1_score_Test_1 = 0.29399746927353226; f_score_Test_1 = [0.57560976 0.30188679 0.53435115 0.         0.10471204]; confusion_matrix_Test_1 = [[59 10  0 14 10]
#  [ 7 48  0  8 42]
#  [ 0 33 35 27  1]
#  [ 0 78  0  0 28]
#  [46 44  0  0 10]]
#
# Axes(0.125,0.11;0.31744x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Accuracy = 27.89% -> 27.82%
#
# Task: s2m, Iter:355/2130; Accuracy_Test_1 = 25.20%; f1_score_Test_1 = 0.26315845503733676; f_score_Test_1 = [0.55958549 0.18685121 0.53435115 0.         0.0862069 ]; confusion_matrix_Test_1 = [[54  3  0 14 22]
#  [ 0 27  0  8 70]
#  [ 0 33 35 27  1]
#  [ 0 77  0  0 29]
#  [46 44  0  0 10]]
#
# Axes(0.125,0.11;0.253952x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Accuracy = 23.76% -> 25.49%
#
# Task: s2m, Iter:426/2130; Accuracy_Test_1 = 30.00%; f1_score_Test_1 = 0.2847351755795647; f_score_Test_1 = [0.5560166  0.14379085 0.53435115 0.         0.24262295]; confusion_matrix_Test_1 = [[67  0  0 14 12]
#  [25 11  0  8 61]
#  [ 0 11 35 42  8]
#  [ 0 19  0  0 87]
#  [56  7  0  0 37]]
#
# Axes(0.125,0.11;0.203162x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Accuracy = 28.31% -> 26.64%
#
# Task: s2m, Iter:497/2130; Accuracy_Test_1 = 28.00%; f1_score_Test_1 = 0.27511185195078963; f_score_Test_1 = [0.55       0.19090909 0.53435115 0.         0.15062762]; confusion_matrix_Test_1 = [[66  0  0 14 13]
#  [25 21  0  8 51]
#  [ 0 19 35 42  0]
#  [ 0 49  0  0 57]
#  [56 26  0  0 18]]
#
# Axes(0.125,0.11;0.162529x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Accuracy = 26.76% -> 26.44%
#
# Task: s2m, Iter:568/2130; Accuracy_Test_1 = 29.00%; f1_score_Test_1 = 0.2793197554581089; f_score_Test_1 = [0.56198347 0.13612565 0.53435115 0.         0.21804511]; confusion_matrix_Test_1 = [[68  0  0 14 11]
#  [25 13  0  8 59]
#  [ 0 19 35 42  0]
#  [ 0 39  0  0 67]
#  [56 15  0  0 29]]
#
# Axes(0.125,0.11;0.130023x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Accuracy = 27.62% -> 27.13%
#
# Task: s2m, Iter:639/2130; Accuracy_Test_1 = 27.00%; f1_score_Test_1 = 0.26596484108384655; f_score_Test_1 = [0.55       0.20689655 0.53435115 0.         0.08810573]; confusion_matrix_Test_1 = [[66  0  0 14 13]
#  [25 24  0  8 48]
#  [ 0 19 35 42  0]
#  [ 0 50  0  0 56]
#  [56 34  0  0 10]]
#
# Axes(0.125,0.11;0.104019x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Accuracy = 26.40% -> 26.44%
#
# Task: s2m, Iter:710/2130; Accuracy_Test_1 = 19.40%; f1_score_Test_1 = 0.18787802665445974; f_score_Test_1 = [0.22       0.14925373 0.39548023 0.         0.1984127 ]; confusion_matrix_Test_1 = [[22  0 46 14 11]
#  [29 15  0  8 53]
#  [ 0 19 35 42  0]
#  [ 0 43  0  0 63]
#  [56 19  0  0 25]]
#
# Axes(0.125,0.11;0.083215x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Accuracy = 18.96% -> 19.31%
#
# Task: s2m, Iter:781/2130; Accuracy_Test_1 = 17.00%; f1_score_Test_1 = 0.15947655764572422; f_score_Test_1 = [0.20853081 0.20224719 0.39548023 0.         0.01142857]; confusion_matrix_Test_1 = [[22  3 46 14  8]
#  [40 27  0  8 30]
#  [ 0 19 35 42  0]
#  [ 0 70  0  0 36]
#  [56 43  0  0  1]]
#
# Axes(0.125,0.11;0.066572x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Accuracy = 16.31% -> 18.27%
#
# Task: s2m, Iter:852/2130; Accuracy_Test_1 = 21.20%; f1_score_Test_1 = 0.19901006154480103; f_score_Test_1 = [0.21698113 0.14545455 0.39548023 0.         0.26086957]; confusion_matrix_Test_1 = [[23  0 46 14 10]
#  [40 12  0  8 45]
#  [ 0 19 35 42  0]
#  [ 0 21  0  0 85]
#  [56  8  0  0 36]]
#
# Axes(0.125,0.11;0.0532576x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Accuracy = 20.18% -> 19.42%
#
# Task: s2m, Iter:923/2130; Accuracy_Test_1 = 19.60%; f1_score_Test_1 = 0.1887242140382885; f_score_Test_1 = [0.21538462 0.14507772 0.39548023 0.         0.21132075]; confusion_matrix_Test_1 = [[21  0 46 14 12]
#  [25 14  0  8 58]
#  [ 0 19 35 42  0]
#  [ 0 39  0  0 67]
#  [56 16  0  0 28]]
#
# Axes(0.125,0.11;0.0426061x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Accuracy = 18.42% -> 19.38%
#
# Task: s2m, Iter:994/2130; Accuracy_Test_1 = 20.60%; f1_score_Test_1 = 0.19958073724591155; f_score_Test_1 = [0.21698113 0.19047619 0.39548023 0.         0.21645022]; confusion_matrix_Test_1 = [[23  0 46 14 10]
#  [40 20  0  8 37]
#  [ 0 19 35 42  0]
#  [ 0 47  0  0 59]
#  [56 19  0  0 25]]
#
# Axes(0.125,0.11;0.0340849x0.77)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Exception ignored in: <function _releaseLock at 0x7f375c3d1bd0>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/logging/__init__.py", line 228, in _releaseLock
#     def _releaseLock():
# KeyboardInterrupt:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1132, in _try_get_data
#     data = self._data_queue.get(timeout=timeout)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 114, in get
#     raise Empty
# _queue.Empty
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/SHOT_IM/uda_digit.py", line 461, in <module>
#     train_target(args)
#   File "/content/drive/MyDrive/SHOT_IM/uda_digit.py", line 311, in train_target
#     mem_label = obtain_label(dset_loaders['target_te'], netF, netB, netC, args)
#   File "/content/drive/MyDrive/SHOT_IM/uda_digit.py", line 367, in obtain_label
#     data = next(iter_test)
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 633, in __next__
#     data = self._next_data()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1328, in _next_data
#     idx, data = self._get_data()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1294, in _get_data
#     success, data = self._try_get_data()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1145, in _try_get_data
#     raise RuntimeError('DataLoader worker (pid(s) {}) exited unexpectedly'.format(pids_str)) from e
# RuntimeError: DataLoader worker (pid(s) 34136, 34138) exited unexpectedly
