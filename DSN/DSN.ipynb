# %% [markdown]
# <a id="section-one"></a>
# ## 1 Import Libraries and download data

# %% [markdown]
# <a id="define-device"></a>
# ### 1.2 Define device

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #OE 2 unbalanced labels

# %%
import pandas as pd
import numpy as np
import random
np.random.seed(2021)

def poison_data(data, rate):
  indx = int(len(data)*rate)
  for i in range(indx):
    data.labels.iloc[i] = random.randint(0,1)

  return data


Final_Data_S1 = pd.read_csv("/content/drive/MyDrive/Final_Data_S1.csv")
Final_Data_S2 = pd.read_csv("/content/drive/MyDrive/Final_Data_S2.csv")

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([3.0, 4.0])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([3.0, 4.0])].index,'labels']=1

# !pip install imbalanced-learn
from imblearn.over_sampling import SMOTE 

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([0.0])].index,'labels']=0
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([1.0])].index,'labels']=1
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([2.0])].index,'labels']=1

Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([0.0])].index,'labels']=0
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([1.0])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([2.0])].index,'labels']=1

labels_S1 = Final_Data_S1.labels
labels_S2 = Final_Data_S2.labels
Data_S1 = Final_Data_S1.drop(['time', 'labels'], axis= 1)
Data_S2 = Final_Data_S2.drop(['time', 'labels'], axis= 1)

from sklearn.decomposition import PCA
pca = PCA(n_components=9)
principalComponents_S1 = pca.fit_transform(Data_S1)
pca = PCA(n_components=9)
principalComponents_S2 = pca.fit_transform(Data_S2)

sm = SMOTE(random_state=2)
principalComponents_S1, labels_S1 = sm.fit_resample(principalComponents_S1, labels_S1)
principalComponents_S2, labels_S2 = sm.fit_resample(principalComponents_S2, labels_S2)

Final_Data_S1 = pd.DataFrame(principalComponents_S1)
Final_Data_S2 = pd.DataFrame(principalComponents_S2)

Final_Data_S1['labels'] = labels_S1
Final_Data_S2['labels'] = labels_S2


Data_0 = Final_Data_S1[Final_Data_S1.labels == 0].iloc[:1045]
Data_2 = Final_Data_S1[Final_Data_S1.labels == 1].iloc[:300]
frames = [Data_0, Data_2]
Final_Data_S1 = pd.concat(frames)

Data_0 = Final_Data_S2[Final_Data_S2.labels == 0].iloc[:772]
Data_2 = Final_Data_S2[Final_Data_S2.labels == 1].iloc[:200]
frames = [Data_0, Data_2]
Final_Data_S2 = pd.concat(frames)

Final_Data_S1 = Final_Data_S1.sample(frac = 1)
Final_Data_S2 = Final_Data_S2.sample(frac = 1)

Source_train = Final_Data_S1.iloc[200:,:]
Source_test = Final_Data_S1.iloc[:200,:]

Target_train = Final_Data_S2.iloc[150:,:]
Target_test = Final_Data_S2.iloc[:150,:]

#Source_train = poison_data(Source_train, 0.1)
#Target_train = poison_data(Target_train, 0.1)

Source_train.to_csv('/content/drive/MyDrive/DSN/data/Source_train.csv', index=False)
Source_test.to_csv('/content/drive/MyDrive/DSN/data/Source_test.csv', index=False)
Target_train.to_csv('/content/drive/MyDrive/DSN/data/Target_train.csv', index=False)
Target_test.to_csv('/content/drive/MyDrive/DSN/data/Target_test.csv', index=False)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.9/dist-packages (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (1.22.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (3.1.0)

# %% [markdown]
# #OE 3 unbalanced labels

# %%
import pandas as pd
import numpy as np
import random
np.random.seed(2021)

def poison_data(data, rate):
  indx = int(len(data)*rate)
  for i in range(indx):
    data.labels.iloc[i] = random.randint(0,2)

  return data
Final_Data_S1 = pd.read_csv("/content/drive/MyDrive/Final_Data_S1.csv")
Final_Data_S2 = pd.read_csv("/content/drive/MyDrive/Final_Data_S2.csv")

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([3.0, 4.0])].index,'labels']=2
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([3.0, 4.0])].index,'labels']=2

# !pip install imbalanced-learn
from imblearn.over_sampling import SMOTE 

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([0.0])].index,'labels']=0
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([1.0])].index,'labels']=1
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([2.0])].index,'labels']=2

Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([0.0])].index,'labels']=0
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([1.0])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([2.0])].index,'labels']=2

labels_S1 = Final_Data_S1.labels
labels_S2 = Final_Data_S2.labels
Data_S1 = Final_Data_S1.drop(['time', 'labels'], axis= 1)
Data_S2 = Final_Data_S2.drop(['time', 'labels'], axis= 1)

from sklearn.decomposition import PCA
pca = PCA(n_components=9)
principalComponents_S1 = pca.fit_transform(Data_S1)
pca = PCA(n_components=9)
principalComponents_S2 = pca.fit_transform(Data_S2)

sm = SMOTE(random_state=2)
principalComponents_S1, labels_S1 = sm.fit_resample(principalComponents_S1, labels_S1)
principalComponents_S2, labels_S2 = sm.fit_resample(principalComponents_S2, labels_S2)

Final_Data_S1 = pd.DataFrame(principalComponents_S1)
Final_Data_S2 = pd.DataFrame(principalComponents_S2)

Final_Data_S1['labels'] = labels_S1
Final_Data_S2['labels'] = labels_S2


Data_0 = Final_Data_S1[Final_Data_S1.labels == 0].iloc[:1045]
Data_2 = Final_Data_S1[Final_Data_S1.labels == 1].iloc[:300]
Data_3 = Final_Data_S1[Final_Data_S1.labels == 2].iloc[:300]
frames = [Data_0, Data_2, Data_3]
Final_Data_S1 = pd.concat(frames)

Data_0 = Final_Data_S2[Final_Data_S2.labels == 0].iloc[:772]
Data_2 = Final_Data_S2[Final_Data_S2.labels == 1].iloc[:200]
Data_3 = Final_Data_S2[Final_Data_S2.labels == 2].iloc[:200]
frames = [Data_0, Data_2, Data_3]
Final_Data_S2 = pd.concat(frames)

Final_Data_S1 = Final_Data_S1.sample(frac = 1)
Final_Data_S2 = Final_Data_S2.sample(frac = 1)

Source_train = Final_Data_S1.iloc[200:,:]
Source_test = Final_Data_S1.iloc[:200,:]

Target_train = Final_Data_S2.iloc[150:,:]
Target_test = Final_Data_S2.iloc[:150,:]

#Source_train = poison_data(Source_train, 0.1)
#Target_train = poison_data(Target_train, 0.1)

Source_train.to_csv('/content/drive/MyDrive/DSN/data/Source_train.csv', index=False)
Source_test.to_csv('/content/drive/MyDrive/DSN/data/Source_test.csv', index=False)
Target_train.to_csv('/content/drive/MyDrive/DSN/data/Target_train.csv', index=False)
Target_test.to_csv('/content/drive/MyDrive/DSN/data/Target_test.csv', index=False)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.9/dist-packages (0.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (1.22.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (1.2.2)

# %% [markdown]
# #OE balanced 2 labels

# %%
import pandas as pd
import numpy as np
import random
np.random.seed(2021)

def poison_data(data, rate):
  indx = int(len(data)*rate)
  for i in range(indx):
    data.labels.iloc[i] = random.randint(0,1)

  return data

Final_Data_S1 = pd.read_csv("/content/drive/MyDrive/Final_Data_S1.csv")
Final_Data_S2 = pd.read_csv("/content/drive/MyDrive/Final_Data_S2.csv")

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([3.0, 4.0])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([3.0, 4.0])].index,'labels']=1

# !pip install imbalanced-learn
from imblearn.over_sampling import SMOTE 

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([0.0])].index,'labels']=0
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([1.0])].index,'labels']=1
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([2.0])].index,'labels']=1

Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([0.0])].index,'labels']=0
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([1.0])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([2.0])].index,'labels']=1

labels_S1 = Final_Data_S1.labels
labels_S2 = Final_Data_S2.labels
Data_S1 = Final_Data_S1.drop(['time', 'labels'], axis= 1)
Data_S2 = Final_Data_S2.drop(['time', 'labels'], axis= 1)

from sklearn.decomposition import PCA
pca = PCA(n_components=9)
principalComponents_S1 = pca.fit_transform(Data_S1)
pca = PCA(n_components=9)
principalComponents_S2 = pca.fit_transform(Data_S2)

sm = SMOTE(random_state=2)
principalComponents_S1, labels_S1 = sm.fit_resample(principalComponents_S1, labels_S1)
principalComponents_S2, labels_S2 = sm.fit_resample(principalComponents_S2, labels_S2)

Final_Data_S1 = pd.DataFrame(principalComponents_S1)
Final_Data_S2 = pd.DataFrame(principalComponents_S2)

Final_Data_S1['labels'] = labels_S1
Final_Data_S2['labels'] = labels_S2


Final_Data_S1 = Final_Data_S1.sample(frac = 1)
Final_Data_S2 = Final_Data_S2.sample(frac = 1)

Source_train = Final_Data_S1.iloc[500:,:]
Source_test = Final_Data_S1.iloc[:500,:]

Target_train = Final_Data_S2.iloc[500:,:]
Target_test = Final_Data_S2.iloc[:500,:]

#Source_train = poison_data(Source_train, 0.1)
#Target_train = poison_data(Target_train, 0.1)

Source_train.to_csv('/content/drive/MyDrive/DSN/data/Source_train.csv', index=False)
Source_test.to_csv('/content/drive/MyDrive/DSN/data/Source_test.csv', index=False)
Target_train.to_csv('/content/drive/MyDrive/DSN/data/Target_train.csv', index=False)
Target_test.to_csv('/content/drive/MyDrive/DSN/data/Target_test.csv', index=False)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.9/dist-packages (0.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (1.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (1.22.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (3.1.0)

# %% [markdown]
# #OE 3 labels balanced

# %%
import pandas as pd
import numpy as np
import random
np.random.seed(2021)

def poison_data(data, rate):
  indx = int(len(data)*rate)
  for i in range(indx):
    data.labels.iloc[i] = random.randint(0,2)

  return data

Final_Data_S1 = pd.read_csv("/content/drive/MyDrive/Final_Data_S1.csv")
Final_Data_S2 = pd.read_csv("/content/drive/MyDrive/Final_Data_S2.csv")


Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([3.0, 4.0])].index,'labels']=2
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([3.0, 4.0])].index,'labels']=2

# !pip install imbalanced-learn
from imblearn.over_sampling import SMOTE 

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([0.0])].index,'labels']=0
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([1.0])].index,'labels']=1
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([2.0])].index,'labels']=2

Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([0.0])].index,'labels']=0
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([1.0])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([2.0])].index,'labels']=2

labels_S1 = Final_Data_S1.labels
labels_S2 = Final_Data_S2.labels
Data_S1 = Final_Data_S1.drop(['time', 'labels'], axis= 1)
Data_S2 = Final_Data_S2.drop(['time', 'labels'], axis= 1)

from sklearn.decomposition import PCA
pca = PCA(n_components=9)
principalComponents_S1 = pca.fit_transform(Data_S1)
pca = PCA(n_components=9)
principalComponents_S2 = pca.fit_transform(Data_S2)

sm = SMOTE(random_state=2)
principalComponents_S1, labels_S1 = sm.fit_resample(principalComponents_S1, labels_S1)
principalComponents_S2, labels_S2 = sm.fit_resample(principalComponents_S2, labels_S2)

Final_Data_S1 = pd.DataFrame(principalComponents_S1)
Final_Data_S2 = pd.DataFrame(principalComponents_S2)

Final_Data_S1['labels'] = labels_S1
Final_Data_S2['labels'] = labels_S2


Final_Data_S1 = Final_Data_S1.sample(frac = 1)
Final_Data_S2 = Final_Data_S2.sample(frac = 1)

Source_train = Final_Data_S1.iloc[500:,:]
Source_test = Final_Data_S1.iloc[:500,:]

Target_train = Final_Data_S2.iloc[500:,:]
Target_test = Final_Data_S2.iloc[:500,:]

#Source_train = poison_data(Source_train, 0.1)
#Target_train = poison_data(Target_train, 0.1)

Source_train.to_csv('/content/drive/MyDrive/DSN/data/Source_train.csv', index=False)
Source_test.to_csv('/content/drive/MyDrive/DSN/data/Source_test.csv', index=False)
Target_train.to_csv('/content/drive/MyDrive/DSN/data/Target_train.csv', index=False)
Target_test.to_csv('/content/drive/MyDrive/DSN/data/Target_test.csv', index=False)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.9/dist-packages (0.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (1.22.4)

# %% [markdown]
# #Load Data AR: 3 Activities

# %%
import pandas as pd 
import numpy as np
np.random.seed(2021)
# !wget http://casas.wsu.edu/datasets/hh101.zip
# !wget http://casas.wsu.edu/datasets/hh105.zip
# !unzip '/content/hh105.zip'
# !unzip /content/hh101.zip

def poison_data(data, rate):
  indx = int(len(data)*rate)
  for i in range(indx):
    data.labels.iloc[i] = random.randint(0,2)
  return data


# !pip install imbalanced-learn
from imblearn.over_sampling import SMOTE

Final_Data_S1 = pd.read_csv("/content/hh101/hh101.ann.features.csv")
Final_Data_S2 = pd.read_csv("/content/hh105/hh105.ann.features.csv")
Final_Data_S1.rename(columns={"activity": "labels"}, inplace= True)
Final_Data_S2.rename(columns={"activity": "labels"}, inplace= True)

Final_Data_S1 = Final_Data_S1.drop(['lastSensorEventHours', 'lastSensorEventSeconds', 'lastSensorDayOfWeek','lastSensorID'], axis= 1)
Final_Data_S2 = Final_Data_S2.drop(['lastSensorEventHours', 'lastSensorEventSeconds','lastSensorDayOfWeek', 'lastSensorID'], axis= 1)

Final_Data_S1 = Final_Data_S1[Final_Data_S1.labels.isin(['Cook_Breakfast',  'Watch_TV', 'Toilet' ])]
Final_Data_S2 = Final_Data_S2[Final_Data_S2.labels.isin([ 'Cook_Breakfast',  'Watch_TV', 'Toilet' ])]

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin(['Watch_TV'])].index,'labels']=0
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin(['Toilet'])].index,'labels']=1
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin(['Cook_Breakfast'])].index,'labels']=2

Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin(['Watch_TV'])].index,'labels']=0
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin(['Toilet'])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin(['Cook_Breakfast'])].index,'labels']=2



Data_0 = Final_Data_S1[Final_Data_S1.labels == 0].iloc[:2000]#2000#4000
Data_2 = Final_Data_S1[Final_Data_S1.labels == 1].iloc[:2000]#2000
Data_3 = Final_Data_S1[Final_Data_S1.labels == 2].iloc[:2000]#2000
frames = [Data_0, Data_2, Data_3]
Final_Data_S1 = pd.concat(frames)

Data_0 = Final_Data_S2[Final_Data_S2.labels == 0].iloc[:1000]#1000#2000
Data_2 = Final_Data_S2[Final_Data_S2.labels == 1].iloc[:1000]#1000
Data_3 = Final_Data_S2[Final_Data_S2.labels == 2].iloc[:1000]#1000
frames = [Data_0, Data_2, Data_3]
Final_Data_S2 = pd.concat(frames)


Final_Data_S1 = Final_Data_S1.sample(frac = 1)
Final_Data_S2 = Final_Data_S2.sample(frac = 1)


Source_train = Final_Data_S1.iloc[200:,:]#1000
Source_test = Final_Data_S1.iloc[:200,:]

Target_train = Final_Data_S2.iloc[150:,:]#500
Target_test = Final_Data_S2.iloc[:150,:]

#Source_train = poison_data(Source_train, 0.1)
#Target_train = poison_data(Target_train, 0.1)

Source_train.to_csv('/content/drive/MyDrive/DSN/data/Source_train.csv', index=False)
Source_test.to_csv('/content/drive/MyDrive/DSN/data/Source_test.csv', index=False)
Target_train.to_csv('/content/drive/MyDrive/DSN/data/Target_train.csv', index=False)
Target_test.to_csv('/content/drive/MyDrive/DSN/data/Target_test.csv', index=False)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.9/dist-packages (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (1.22.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn) (1.2.0)

# %% [markdown]
# #Load Data AR: 5 Activities

# %%
import pandas as pd 
import numpy as np
import random
np.random.seed(2021)
# !wget http://casas.wsu.edu/datasets/hh101.zip
# !wget http://casas.wsu.edu/datasets/hh105.zip
# !unzip '/content/hh105.zip'
# !unzip /content/hh101.zip

def poison_data(data, rate):
  indx = int(len(data)*rate)
  for i in range(indx):
    data.labels.iloc[i] = random.randint(0,4)
  return data

Final_Data_S1 = pd.read_csv("/content/hh101/hh101.ann.features.csv")
Final_Data_S2 = pd.read_csv("/content/hh105/hh105.ann.features.csv")
Final_Data_S1.rename(columns={"activity": "labels"}, inplace= True)
Final_Data_S2.rename(columns={"activity": "labels"}, inplace= True)

Final_Data_S1 = Final_Data_S1.drop(['lastSensorEventHours', 'lastSensorEventSeconds', 'lastSensorDayOfWeek','lastSensorID'], axis= 1)
Final_Data_S2 = Final_Data_S2.drop(['lastSensorEventHours', 'lastSensorEventSeconds','lastSensorDayOfWeek', 'lastSensorID'], axis= 1)

Final_Data_S1 = Final_Data_S1[Final_Data_S1.labels.isin(['Cook_Dinner', 'Cook_Breakfast', 'Cook_Lunch', 'Watch_TV', 'Toilet' ])]
Final_Data_S2 = Final_Data_S2[Final_Data_S2.labels.isin(['Cook_Dinner', 'Cook_Breakfast', 'Cook_Lunch', 'Watch_TV', 'Toilet' ])]

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin(['Watch_TV'])].index,'labels']=0
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin(['Cook_Lunch'])].index,'labels']=1
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin(['Toilet'])].index,'labels']=2
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin(['Cook_Breakfast'])].index,'labels']=3
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin(['Cook_Dinner'])].index,'labels']=4

Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin(['Watch_TV'])].index,'labels']=0
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin(['Cook_Lunch'])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin(['Toilet'])].index,'labels']=2
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin(['Cook_Breakfast'])].index,'labels']=3
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin(['Cook_Dinner'])].index,'labels']=4

Data_0 = Final_Data_S1[Final_Data_S1.labels == 0].iloc[:4000]#2000#4000
Data_1 = Final_Data_S1[Final_Data_S1.labels == 1].iloc[:4000]#4000
Data_2 = Final_Data_S1[Final_Data_S1.labels == 2].iloc[:2000]#2000
Data_3 = Final_Data_S1[Final_Data_S1.labels == 3].iloc[:4000]#4000
Data_4 = Final_Data_S1[Final_Data_S1.labels == 4].iloc[:2000]#
frames = [Data_0, Data_1, Data_2, Data_3, Data_4]
Final_Data_S1 = pd.concat(frames)

Data_0 = Final_Data_S2[Final_Data_S2.labels == 0].iloc[:2000]#1000#2000
Data_1 = Final_Data_S2[Final_Data_S2.labels == 1].iloc[:2000]#2000
Data_2 = Final_Data_S2[Final_Data_S2.labels == 2].iloc[:1000]#
Data_3 = Final_Data_S2[Final_Data_S2.labels == 3].iloc[:2000]#2000
Data_4 = Final_Data_S2[Final_Data_S2.labels == 4].iloc[:1000]#
frames = [Data_0, Data_1, Data_2, Data_3, Data_4]
Final_Data_S2 = pd.concat(frames)


Final_Data_S1 = Final_Data_S1.sample(frac = 1)
Final_Data_S2 = Final_Data_S2.sample(frac = 1)

Source_train = Final_Data_S1.iloc[200:,:]#1000#
Source_test = Final_Data_S1.iloc[:200,:]

Target_train = Final_Data_S2.iloc[150:,:]#500#
Target_test = Final_Data_S2.iloc[:150,:]

#Source_train = poison_data(Source_train, 0.1)
#Target_train = poison_data(Target_train, 0.1)

Source_train.to_csv('/content/drive/MyDrive/DSN/data/Source_train.csv', index=False)
Source_test.to_csv('/content/drive/MyDrive/DSN/data/Source_test.csv', index=False)
Target_train.to_csv('/content/drive/MyDrive/DSN/data/Target_train.csv', index=False)
Target_test.to_csv('/content/drive/MyDrive/DSN/data/Target_test.csv', index=False)

# %%
import os
os.chdir('/content/drive/MyDrive/DSN')

# %%
# !python train.py
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# learning rate is set to 0.010000
# source_classification: -0.000000, source_dann: 0.000000, source_diff: 0.006683, source_mse: 0.012366, source_simse: 0.000067, target_dann: 0.000000, target_diff: 0.002676, target_mse: 0.018212, target_simse: 0.000495
# epoch: 0, accuracy of the mnist dataset: 0.494000
# epoch: 0, F1-score of the mnist dataset: 0.420793
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch: 0, accuracy of the mnist_m dataset: 0.560000
# epoch: 0, F1-score of the mnist_m dataset: 0.456466
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# source_classification: -0.000000, source_dann: 0.000000, source_diff: 0.004990, source_mse: 0.011096, source_simse: 0.000003, target_dann: 0.000000, target_diff: 0.002046, target_mse: 0.016981, target_simse: 0.000310
# epoch: 1, accuracy of the mnist dataset: 0.494000
# epoch: 1, F1-score of the mnist dataset: 0.420793
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch: 1, accuracy of the mnist_m dataset: 0.560000
# epoch: 1, F1-score of the mnist_m dataset: 0.456466
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# source_classification: -0.000000, source_dann: 0.000000, source_diff: 0.000119, source_mse: 0.012554, source_simse: 0.000056, target_dann: 0.000000, target_diff: 0.000084, target_mse: 0.019018, target_simse: 0.000135
# epoch: 2, accuracy of the mnist dataset: 0.494000
# epoch: 2, F1-score of the mnist dataset: 0.420793
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch: 2, accuracy of the mnist_m dataset: 0.560000
# epoch: 2, F1-score of the mnist_m dataset: 0.456466
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# source_classification: -0.000000, source_dann: 0.000000, source_diff: 0.000077, source_mse: 0.011918, source_simse: 0.000001, target_dann: 0.000000, target_diff: 0.000040, target_mse: 0.016974, target_simse: 0.000071
# epoch: 3, accuracy of the mnist dataset: 0.494000
# epoch: 3, F1-score of the mnist dataset: 0.420793
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch: 3, accuracy of the mnist_m dataset: 0.560000
# epoch: 3, F1-score of the mnist_m dataset: 0.456466
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# source_classification: -0.000000, source_dann: 0.000000, source_diff: 0.000000, source_mse: 0.009804, source_simse: 0.000000, target_dann: 0.000000, target_diff: 0.000000, target_mse: 0.011137, target_simse: 0.000016
# epoch: 4, accuracy of the mnist dataset: 0.494000
# epoch: 4, F1-score of the mnist dataset: 0.420793
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch: 4, accuracy of the mnist_m dataset: 0.560000
# epoch: 4, F1-score of the mnist_m dataset: 0.456466
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# source_classification: -0.000000, source_dann: 0.000000, source_diff: 0.000017, source_mse: 0.016951, source_simse: 0.000006, target_dann: 0.000000, target_diff: 0.000007, target_mse: 0.012748, target_simse: 0.000127
# epoch: 5, accuracy of the mnist dataset: 0.494000
# epoch: 5, F1-score of the mnist dataset: 0.420793
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch: 5, accuracy of the mnist_m dataset: 0.560000
# epoch: 5, F1-score of the mnist_m dataset: 0.456466
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# source_classification: -0.000000, source_dann: 0.000000, source_diff: 0.000000, source_mse: 0.007109, source_simse: 0.000049, target_dann: 0.000000, target_diff: 0.000007, target_mse: 0.014055, target_simse: 0.000114
# epoch: 6, accuracy of the mnist dataset: 0.494000
# epoch: 6, F1-score of the mnist dataset: 0.420793
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch: 6, accuracy of the mnist_m dataset: 0.560000
# epoch: 6, F1-score of the mnist_m dataset: 0.456466
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# source_classification: -0.000000, source_dann: 0.000000, source_diff: 0.000000, source_mse: 0.010078, source_simse: 0.000009, target_dann: 0.000000, target_diff: 0.000000, target_mse: 0.011271, target_simse: 0.000053
# epoch: 7, accuracy of the mnist dataset: 0.494000
# epoch: 7, F1-score of the mnist dataset: 0.420793
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch: 7, accuracy of the mnist_m dataset: 0.560000
# epoch: 7, F1-score of the mnist_m dataset: 0.456466
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# source_classification: -0.000000, source_dann: 0.000000, source_diff: 0.000000, source_mse: 0.010215, source_simse: 0.000008, target_dann: 0.000000, target_diff: 0.000000, target_mse: 0.013540, target_simse: 0.000072
# epoch: 8, accuracy of the mnist dataset: 0.494000
# epoch: 8, F1-score of the mnist dataset: 0.420793
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch: 8, accuracy of the mnist_m dataset: 0.560000
# epoch: 8, F1-score of the mnist_m dataset: 0.456466
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# source_classification: -0.000000, source_dann: 0.000000, source_diff: 0.000000, source_mse: 0.006610, source_simse: 0.000000, target_dann: 0.000000, target_diff: 0.000000, target_mse: 0.013474, target_simse: 0.000134
# epoch: 9, accuracy of the mnist dataset: 0.494000
# epoch: 9, F1-score of the mnist dataset: 0.420793
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch: 9, accuracy of the mnist_m dataset: 0.560000
# epoch: 9, F1-score of the mnist_m dataset: 0.456466
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# source_classification: -0.000000, source_dann: 0.000000, source_diff: 0.000000, source_mse: 0.011948, source_simse: 0.000000, target_dann: 0.000000, target_diff: 0.000000, target_mse: 0.012645, target_simse: 0.000027
# epoch: 10, accuracy of the mnist dataset: 0.494000
# epoch: 10, F1-score of the mnist dataset: 0.420793
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch: 10, accuracy of the mnist_m dataset: 0.560000
# epoch: 10, F1-score of the mnist_m dataset: 0.456466
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# source_classification: -0.000000, source_dann: 0.000000, source_diff: 0.000000, source_mse: 0.013242, source_simse: 0.000134, target_dann: 0.000000, target_diff: 0.000000, target_mse: 0.025807, target_simse: 0.000685
# epoch: 11, accuracy of the mnist dataset: 0.494000
# epoch: 11, F1-score of the mnist dataset: 0.420793
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch: 11, accuracy of the mnist_m dataset: 0.560000
# epoch: 11, F1-score of the mnist_m dataset: 0.456466
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# source_classification: -0.000000, source_dann: 0.000000, source_diff: 0.000000, source_mse: 0.008219, source_simse: 0.000041, target_dann: 0.000000, target_diff: 0.000000, target_mse: 0.009722, target_simse: 0.000002
# epoch: 12, accuracy of the mnist dataset: 0.494000
# epoch: 12, F1-score of the mnist dataset: 0.420793
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch: 12, accuracy of the mnist_m dataset: 0.560000
# epoch: 12, F1-score of the mnist_m dataset: 0.456466
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# source_classification: -0.000000, source_dann: 0.000000, source_diff: 0.000000, source_mse: 0.012252, source_simse: 0.000008, target_dann: 0.000000, target_diff: 0.000000, target_mse: 0.015421, target_simse: 0.000003
# epoch: 13, accuracy of the mnist dataset: 0.494000
# epoch: 13, F1-score of the mnist dataset: 0.420793
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch: 13, accuracy of the mnist_m dataset: 0.560000
# epoch: 13, F1-score of the mnist_m dataset: 0.456466
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# source_classification: -0.000000, source_dann: 0.000000, source_diff: 0.000007, source_mse: 0.016395, source_simse: 0.000001, target_dann: 0.000000, target_diff: 0.000000, target_mse: 0.011730, target_simse: 0.000103
# epoch: 14, accuracy of the mnist dataset: 0.494000
# epoch: 14, F1-score of the mnist dataset: 0.420793
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch: 14, accuracy of the mnist_m dataset: 0.560000
# epoch: 14, F1-score of the mnist_m dataset: 0.456466
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# source_classification: -0.000000, source_dann: 0.000000, source_diff: 0.000000, source_mse: 0.008709, source_simse: 0.000008, target_dann: 0.000000, target_diff: 0.000000, target_mse: 0.014768, target_simse: 0.000301
# epoch: 15, accuracy of the mnist dataset: 0.494000
# epoch: 15, F1-score of the mnist dataset: 0.420793
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch: 15, accuracy of the mnist_m dataset: 0.560000
# epoch: 15, F1-score of the mnist_m dataset: 0.456466
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# source_classification: -0.000000, source_dann: 0.000000, source_diff: 0.000007, source_mse: 0.009644, source_simse: 0.000011, target_dann: 0.000000, target_diff: 0.000000, target_mse: 0.016789, target_simse: 0.000163
# epoch: 16, accuracy of the mnist dataset: 0.494000
# epoch: 16, F1-score of the mnist dataset: 0.420793
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch: 16, accuracy of the mnist_m dataset: 0.560000
# epoch: 16, F1-score of the mnist_m dataset: 0.456466
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# source_classification: -0.000000, source_dann: 0.000000, source_diff: 0.000000, source_mse: 0.005070, source_simse: 0.000173, target_dann: 0.000000, target_diff: 0.000000, target_mse: 0.008491, target_simse: 0.000034
# epoch: 17, accuracy of the mnist dataset: 0.494000
# epoch: 17, F1-score of the mnist dataset: 0.420793
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch: 17, accuracy of the mnist_m dataset: 0.560000
# epoch: 17, F1-score of the mnist_m dataset: 0.456466
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# source_classification: -0.000000, source_dann: 0.000000, source_diff: 0.000000, source_mse: 0.014100, source_simse: 0.000030, target_dann: 0.000000, target_diff: 0.000000, target_mse: 0.012218, target_simse: 0.000011
# epoch: 18, accuracy of the mnist dataset: 0.494000
# epoch: 18, F1-score of the mnist dataset: 0.420793
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch: 18, accuracy of the mnist_m dataset: 0.560000
# epoch: 18, F1-score of the mnist_m dataset: 0.456466
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# source_classification: -0.000000, source_dann: 0.000000, source_diff: 0.000000, source_mse: 0.011740, source_simse: 0.000077, target_dann: 0.000000, target_diff: 0.000000, target_mse: 0.011001, target_simse: 0.000000
# epoch: 19, accuracy of the mnist dataset: 0.494000
# epoch: 19, F1-score of the mnist dataset: 0.420793
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch: 19, accuracy of the mnist_m dataset: 0.560000
# epoch: 19, F1-score of the mnist_m dataset: 0.456466
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# source_classification: -0.000000, source_dann: 0.000000, source_diff: 0.000007, source_mse: 0.012763, source_simse: 0.000010, target_dann: 0.000000, target_diff: 0.000000, target_mse: 0.021067, target_simse: 0.000447
# epoch: 20, accuracy of the mnist dataset: 0.494000
# epoch: 20, F1-score of the mnist dataset: 0.420793
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch: 20, accuracy of the mnist_m dataset: 0.560000
# epoch: 20, F1-score of the mnist_m dataset: 0.456466
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Traceback (most recent call last):
#   File "/content/drive/.shortcut-targets-by-id/1Yl7Yf8gpM7-pA8XPY-IhmHBM1ZnTmves/DSN/train.py", line 288, in <module>
#     source_diff = beta_weight * loss_diff(source_privte_code, source_share_code)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/content/drive/.shortcut-targets-by-id/1Yl7Yf8gpM7-pA8XPY-IhmHBM1ZnTmves/DSN/functions.py", line 63, in forward
#     diff_loss = torch.mean((input1_l2.t().mm(input2_l2)).pow(2))
# KeyboardInterrupt
# ^C
